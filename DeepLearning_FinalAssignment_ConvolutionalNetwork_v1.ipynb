# %%
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data preparation

# %% [markdown]
#  As the Kaggle entry states, the folder 'dataset2-master' contains 2,500 augmented images with 4 additional subtype labels (JPEG + CSV).

# %%
## Make path variable and determine desired image dimensions
# test_path = r'/homes/maschepers/Documents/Cell_data_DeepLearning/dataset2-master/dataset2-master/images/TEST/'
# train_path = r'/homes/maschepers/Documents/Cell_data_DeepLearning/dataset2-master/dataset2-master/images/TRAIN/'

test_path = r'C:\\Users\\Martin Schepers\\Documents\\dataset2-master\\dataset2-master\\images\\TEST\\'
train_path = r'C:\\Users\\Martin Schepers\\Documents\\dataset2-master\\dataset2-master\\images\\TRAIN\\'

train_data = keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
train_generator = train_data.flow_from_directory(
    directory=train_path,
    batch_size=20,
    color_mode='rgb',
    target_size=(120, 160),
    class_mode='categorical'
)

test_data = keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
test_generator = test_data.flow_from_directory(
    directory=test_path,
    batch_size=20,
    color_mode='rgb',
    target_size=(120, 160),
    class_mode='categorical'
)
# Out:
# Found 9957 images belonging to 4 classes.
# Found 2487 images belonging to 4 classes.

# %%
for x_train, y_train in train_generator:
    print(x_train.shape, x_train.dtype)
    print(y_train.shape, y_train.dtype)
    break
# Out:
# (20, 120, 160, 3) float32
# (20, 4) float32

# %%
import matplotlib.pyplot as plt
for i in range(0, 10):
    plt.imshow(x_train[i])
    plt.title(str(y_train[i]))
    plt.show()

# %% [markdown]
# ## Deep learning model creation

# %%
celclass = keras.models.Sequential()
celclass.add(keras.layers.InputLayer(input_shape=(120, 160, 3)))
# First convolutional layer
celclass.add(keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
celclass.add(keras.layers.MaxPooling2D())
celclass.add(keras.layers.Dropout(0.3))

# Second convolutional layer
celclass.add(keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
celclass.add(keras.layers.MaxPooling2D())
# celclass.add(keras.layers.Dropout(0.3))

# Third convolutional layer
celclass.add(keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
celclass.add(keras.layers.MaxPooling2D())

# Dense layer
celclass.add(keras.layers.Flatten())
celclass.add(keras.layers.Dense(units=64, activation='relu'))

# Output layer
celclass.add(keras.layers.Dense(units=4, activation='softmax'))

celclass.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 118, 158, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 59, 79, 32)       0
#  )
#
#  dropout (Dropout)           (None, 59, 79, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 57, 77, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 38, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 26, 36, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 29952)             0
#
#  dense (Dense)               (None, 64)                1916992
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2,010,500
# Trainable params: 2,010,500
# Non-trainable params: 0
# _________________________________________________________________

# %%
celclass.compile(
    loss=keras.losses.CategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=keras.metrics.CategoricalAccuracy()
)

# %%
# history = celclass.fit(train_generator, validation_data=test_generator, epochs=30)

history = celclass.fit_generator(generator=train_generator,
                                 epochs=30,
                                 steps_per_epoch=300,
                                 validation_data=test_generator,
                                 validation_steps=50
                                )

# history = celclass.fit(train_generator,
#                        epochs=30,
#                        validation_data = test_generator
#                       )

history.history.keys()
# Out:
# Epoch 1/30
# C:\Users\MARTIN~1\AppData\Local\Temp/ipykernel_16152/675684954.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = celclass.fit_generator(generator=train_generator,
# 300/300 [==============================] - 59s 194ms/step - loss: 1.3911 - categorical_accuracy: 0.2470 - val_loss: 1.3863 - val_categorical_accuracy: 0.2490
# Epoch 2/30
# 300/300 [==============================] - 59s 197ms/step - loss: 1.3865 - categorical_accuracy: 0.2485 - val_loss: 1.3864 - val_categorical_accuracy: 0.2460
# Epoch 3/30
# 300/300 [==============================] - 60s 198ms/step - loss: 1.3866 - categorical_accuracy: 0.2417 - val_loss: 1.3864 - val_categorical_accuracy: 0.2420
# Epoch 4/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3871 - categorical_accuracy: 0.2400 - val_loss: 1.3864 - val_categorical_accuracy: 0.2260
# Epoch 5/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3864 - categorical_accuracy: 0.2463 - val_loss: 1.3867 - val_categorical_accuracy: 0.2440
# Epoch 6/30
# 300/300 [==============================] - 60s 199ms/step - loss: 1.3868 - categorical_accuracy: 0.2532 - val_loss: 1.3858 - val_categorical_accuracy: 0.2610
# Epoch 7/30
# 300/300 [==============================] - 60s 199ms/step - loss: 1.3865 - categorical_accuracy: 0.2557 - val_loss: 1.3864 - val_categorical_accuracy: 0.2520
# Epoch 8/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3865 - categorical_accuracy: 0.2460 - val_loss: 1.3862 - val_categorical_accuracy: 0.2480
# Epoch 9/30
# 300/300 [==============================] - 60s 199ms/step - loss: 1.3864 - categorical_accuracy: 0.2460 - val_loss: 1.3867 - val_categorical_accuracy: 0.2500
# Epoch 10/30
# 300/300 [==============================] - 60s 198ms/step - loss: 1.3866 - categorical_accuracy: 0.2418 - val_loss: 1.3863 - val_categorical_accuracy: 0.2530
# Epoch 11/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3865 - categorical_accuracy: 0.2441 - val_loss: 1.3862 - val_categorical_accuracy: 0.2690
# Epoch 12/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3865 - categorical_accuracy: 0.2520 - val_loss: 1.3859 - val_categorical_accuracy: 0.2610
# Epoch 13/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3865 - categorical_accuracy: 0.2462 - val_loss: 1.3862 - val_categorical_accuracy: 0.2620
# Epoch 14/30
# 300/300 [==============================] - 60s 198ms/step - loss: 1.3864 - categorical_accuracy: 0.2495 - val_loss: 1.3861 - val_categorical_accuracy: 0.2600
# Epoch 15/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3866 - categorical_accuracy: 0.2451 - val_loss: 1.3858 - val_categorical_accuracy: 0.2770
# Epoch 16/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3865 - categorical_accuracy: 0.2496 - val_loss: 1.3864 - val_categorical_accuracy: 0.2460
# Epoch 17/30
# 300/300 [==============================] - 60s 199ms/step - loss: 1.3865 - categorical_accuracy: 0.2395 - val_loss: 1.3862 - val_categorical_accuracy: 0.2600
# Epoch 18/30
# 300/300 [==============================] - 60s 199ms/step - loss: 1.3865 - categorical_accuracy: 0.2466 - val_loss: 1.3864 - val_categorical_accuracy: 0.2540
# Epoch 19/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3864 - categorical_accuracy: 0.2468 - val_loss: 1.3866 - val_categorical_accuracy: 0.2360
# Epoch 20/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3864 - categorical_accuracy: 0.2498 - val_loss: 1.3867 - val_categorical_accuracy: 0.2370
# Epoch 21/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3863 - categorical_accuracy: 0.2563 - val_loss: 1.3858 - val_categorical_accuracy: 0.2710
# Epoch 22/30
# 300/300 [==============================] - 60s 199ms/step - loss: 1.3866 - categorical_accuracy: 0.2481 - val_loss: 1.3863 - val_categorical_accuracy: 0.2470
# Epoch 23/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3865 - categorical_accuracy: 0.2383 - val_loss: 1.3864 - val_categorical_accuracy: 0.2450
# Epoch 24/30
# 300/300 [==============================] - 60s 198ms/step - loss: 1.3864 - categorical_accuracy: 0.2433 - val_loss: 1.3864 - val_categorical_accuracy: 0.2400
# Epoch 25/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3863 - categorical_accuracy: 0.2563 - val_loss: 1.3864 - val_categorical_accuracy: 0.2510
# Epoch 26/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3865 - categorical_accuracy: 0.2506 - val_loss: 1.3862 - val_categorical_accuracy: 0.2580
# Epoch 27/30
# 300/300 [==============================] - 59s 198ms/step - loss: 1.3864 - categorical_accuracy: 0.2500 - val_loss: 1.3865 - val_categorical_accuracy: 0.2460
# Epoch 28/30
# 288/300 [===========================>..] - ETA: 2s - loss: 1.3865 - categorical_accuracy: 0.2454

# %%
plt.plot(history.history['loss'], 'go', label='Training loss')
plt.plot(history.history['val_loss'], 'g-', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['categorical_accuracy'], 'go', label='Categorical accuracy')
plt.plot(history.history['val_categorical_accuracy'], 'g-', label='Validation categorical accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
