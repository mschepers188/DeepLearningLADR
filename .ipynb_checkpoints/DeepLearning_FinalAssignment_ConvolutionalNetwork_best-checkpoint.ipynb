# %%
from tensorflow import keras
from keras.models import load_model
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data preparation

# %% [markdown]
#  As the Kaggle entry states, the folder 'dataset2-master' contains 2,500 augmented images with 4 additional subtype labels (JPEG + CSV).

# %%
# Make path variable and determine desired image dimensions
# test_path = r'/homes/maschepers/Documents/Cell_data_DeepLearning/dataset2-master/dataset2-master/images/TEST/'
# train_path = r'/homes/maschepers/Documents/Cell_data_DeepLearning/dataset2-master/dataset2-master/images/TRAIN/'

test_path = r'C:\\Users\\Martin Schepers\\Documents\\dataset2-master\\dataset2-master\\images\\TEST\\'
train_path = r'C:\\Users\\Martin Schepers\\Documents\\dataset2-master\\dataset2-master\\images\\TRAIN\\'


train_data = keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
train_generator = train_data.flow_from_directory(
    directory=train_path,
    batch_size=20,
    color_mode='rgb',
    target_size=(120, 160),
    class_mode='categorical'
)

test_data = keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
test_generator = test_data.flow_from_directory(
    directory=test_path,
    batch_size=20,
    color_mode='rgb',
    target_size=(120, 160),
    class_mode='categorical'
)
# Out:
# Found 9957 images belonging to 4 classes.
# Found 2487 images belonging to 4 classes.

# %%
for x_train, y_train in train_generator:
    print(x_train.shape, x_train.dtype)
    print(y_train.shape, y_train.dtype)
    break
# Out:
# (20, 120, 160, 3) float32
# (20, 4) float32

# %%
import matplotlib.pyplot as plt
for i in range(0, 10):
    plt.imshow(x_train[i])
    plt.title(str(y_train[i]))
    plt.show()

# %% [markdown]
# ## Deep learning model creation

# %%
#### Change to leaky relu! So far best
#### Perhaps higher dropout?

celclass = keras.models.Sequential()
celclass.add(keras.layers.InputLayer(input_shape=(120, 160, 3)))
# First convolutional layer
celclass.add(keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
celclass.add(keras.layers.MaxPooling2D())
celclass.add(keras.layers.Dropout(0.2))

# Second convolutional layer
celclass.add(keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
celclass.add(keras.layers.MaxPooling2D())
celclass.add(keras.layers.Dropout(0.2))

# Third convolutional layer
celclass.add(keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
celclass.add(keras.layers.MaxPooling2D())

# Dense layer
celclass.add(keras.layers.Flatten())
celclass.add(keras.layers.Dense(units=64, activation='relu'))
celclass.add(keras.layers.Dropout(0.3))
# Output layer
celclass.add(keras.layers.Dense(units=4, activation='softmax'))

celclass.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 118, 158, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 59, 79, 32)       0
#  )
#
#  dropout (Dropout)           (None, 59, 79, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 57, 77, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 38, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 28, 38, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 26, 36, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 29952)             0
#
#  dense (Dense)               (None, 64)                1916992
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2,010,500
# Trainable params: 2,010,500
# Non-trainable params: 0
# _________________________________________________________________

# %%
celclass.compile(
    loss=keras.losses.CategoricalCrossentropy(),
    optimizer=keras.optimizers.RMSprop(),
    metrics=keras.metrics.CategoricalAccuracy()
)

# keras.losses.SparseCategoricalCrossentropy()

# %%
# history = celclass.fit(train_generator, validation_data=test_generator, epochs=30)

history = celclass.fit_generator(generator=train_generator,
                                 epochs=30,
                                 steps_per_epoch=300,
                                 validation_data=test_generator,
                                 validation_steps=50
                                )
# Out:
# Epoch 1/30
# C:\Users\MARTIN~1\AppData\Local\Temp/ipykernel_8552/3281826609.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = celclass.fit_generator(generator=train_generator,
# 300/300 [==============================] - 65s 214ms/step - loss: 1.8337 - categorical_accuracy: 0.2768 - val_loss: 1.3403 - val_categorical_accuracy: 0.3540
# Epoch 2/30
# 300/300 [==============================] - 65s 218ms/step - loss: 1.3695 - categorical_accuracy: 0.3687 - val_loss: 1.3112 - val_categorical_accuracy: 0.3440
# Epoch 3/30
# 300/300 [==============================] - 65s 218ms/step - loss: 1.2670 - categorical_accuracy: 0.4328 - val_loss: 1.1702 - val_categorical_accuracy: 0.4610
# Epoch 4/30
# 300/300 [==============================] - 65s 218ms/step - loss: 1.1652 - categorical_accuracy: 0.4892 - val_loss: 1.0944 - val_categorical_accuracy: 0.4620
# Epoch 5/30
# 300/300 [==============================] - 66s 218ms/step - loss: 1.0556 - categorical_accuracy: 0.5373 - val_loss: 1.0434 - val_categorical_accuracy: 0.5000
# Epoch 6/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.9348 - categorical_accuracy: 0.6033 - val_loss: 1.2791 - val_categorical_accuracy: 0.4670
# Epoch 7/30
# 300/300 [==============================] - 66s 220ms/step - loss: 0.8362 - categorical_accuracy: 0.6477 - val_loss: 0.9094 - val_categorical_accuracy: 0.5640
# Epoch 8/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.7482 - categorical_accuracy: 0.6937 - val_loss: 1.0532 - val_categorical_accuracy: 0.5330
# Epoch 9/30
# 300/300 [==============================] - 66s 218ms/step - loss: 0.6526 - categorical_accuracy: 0.7430 - val_loss: 0.8990 - val_categorical_accuracy: 0.6390
# Epoch 10/30
# 300/300 [==============================] - 66s 220ms/step - loss: 0.6174 - categorical_accuracy: 0.7514 - val_loss: 0.9181 - val_categorical_accuracy: 0.5710
# Epoch 11/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.5407 - categorical_accuracy: 0.7833 - val_loss: 0.7899 - val_categorical_accuracy: 0.6810
# Epoch 12/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.5490 - categorical_accuracy: 0.7934 - val_loss: 0.8411 - val_categorical_accuracy: 0.6620
# Epoch 13/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.4852 - categorical_accuracy: 0.8166 - val_loss: 0.8922 - val_categorical_accuracy: 0.6620
# Epoch 14/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.4548 - categorical_accuracy: 0.8267 - val_loss: 3.4919 - val_categorical_accuracy: 0.4350
# Epoch 15/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.4029 - categorical_accuracy: 0.8441 - val_loss: 1.0016 - val_categorical_accuracy: 0.6230
# Epoch 16/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.4129 - categorical_accuracy: 0.8488 - val_loss: 0.8346 - val_categorical_accuracy: 0.6770
# Epoch 17/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.3594 - categorical_accuracy: 0.8654 - val_loss: 0.9633 - val_categorical_accuracy: 0.6540
# Epoch 18/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.3448 - categorical_accuracy: 0.8663 - val_loss: 0.8952 - val_categorical_accuracy: 0.6770
# Epoch 19/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.3253 - categorical_accuracy: 0.8782 - val_loss: 1.2444 - val_categorical_accuracy: 0.6390
# Epoch 20/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.3088 - categorical_accuracy: 0.8876 - val_loss: 0.9168 - val_categorical_accuracy: 0.6720
# Epoch 21/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.2866 - categorical_accuracy: 0.8879 - val_loss: 1.3009 - val_categorical_accuracy: 0.6470
# Epoch 22/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.3018 - categorical_accuracy: 0.9011 - val_loss: 1.0920 - val_categorical_accuracy: 0.6810
# Epoch 23/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.2815 - categorical_accuracy: 0.8990 - val_loss: 1.0679 - val_categorical_accuracy: 0.6920
# Epoch 24/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.2531 - categorical_accuracy: 0.9103 - val_loss: 1.6191 - val_categorical_accuracy: 0.6560
# Epoch 25/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.2538 - categorical_accuracy: 0.9056 - val_loss: 0.9733 - val_categorical_accuracy: 0.7020
# Epoch 26/30
# 300/300 [==============================] - 66s 220ms/step - loss: 0.2374 - categorical_accuracy: 0.9125 - val_loss: 1.3167 - val_categorical_accuracy: 0.5870
# Epoch 27/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.2181 - categorical_accuracy: 0.9155 - val_loss: 0.9867 - val_categorical_accuracy: 0.7140
# Epoch 28/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.2888 - categorical_accuracy: 0.9127 - val_loss: 0.9924 - val_categorical_accuracy: 0.6860
# Epoch 29/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.2196 - categorical_accuracy: 0.9236 - val_loss: 0.8572 - val_categorical_accuracy: 0.7120
# Epoch 30/30
# 300/300 [==============================] - 66s 219ms/step - loss: 0.2081 - categorical_accuracy: 0.9246 - val_loss: 1.1964 - val_categorical_accuracy: 0.6370

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])

# %%
plt.plot(history.history['loss'], 'go', label='Training loss')
plt.plot(history.history['val_loss'], 'g-', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['categorical_accuracy'], 'go', label='Categorical accuracy')
plt.plot(history.history['val_categorical_accuracy'], 'g-', label='Validation categorical accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #### Observations
#
# Using Adam, the model kept stagnating at loss 1.38 and it woudn't get better then random guessing (25% accuracy). Changing to RMSprop caused the model to immediately perform very well, using 2 dropout layers after the convolutional layers and one after the dense layer caused the model to easily make it to about 80% accuracy before starting to overfit.
#
# Trying to apply additional regularizers such as L1L2 and batch normalization quickly caused the model to perform poorly or severely start overfit at the first 10 epochs.

# %%
filepath = "weights_2022-06-22_test5_leakyrelu.h5"

celclass.save(
    filepath,
    overwrite=True,
    include_optimizer=True,
    save_format=None,
    signatures=None,
    options=None,
    save_traces=True,
)
# save_model_weights_hdf5(celclass, filepath, overwrite = TRUE)
