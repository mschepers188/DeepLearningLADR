# %%
import faces
# Out:
# 2022-06-13 10:35:19.023069: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-13 10:35:19.023114: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
(x_train, y_train), (x_test, y_test) = faces.load_data()
# Out:
# Downloading data from https://bioinf.nl/~davelangers/datasets/faces.npz
# 141985975/141985975 [==============================] - 1s 0us/step

# %%
x_train.shape, x_train.dtype
# Out:
# ((10000, 64, 64, 3), dtype('uint8'))

# %%
y_train.shape, y_train.dtype
# Out:
# ((10000, 3), dtype('uint8'))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
for img in range(30):
    plt.subplot(3, 10, img+1)
    plt.imshow(x_train[img], cmap=plt.cm.binary)
    plt.axis(False)
    plt.title(y_train[img])
plt.show()
# Out:
# /commons/conda/lib/python3.8/site-packages/matplotlib/text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
x_train = x_train/255
x_test = x_test/255

# %%
x_train.shape, x_train.dtype
# Out:
# ((10000, 64, 64, 3), dtype('float64'))

# %%
# Deep learning 
from tensorflow import keras

# create model
neural = keras.models.Sequential()

neural.add(keras.layers.InputLayer(input_shape=(64, 64, 3), name='Input'))
neural.add(keras.layers.Flatten())
neural.add(keras.layers.Dense(units=256, activation='relu', name='Hidden_1'))
neural.add(keras.layers.Dense(units=64, activation='relu', name='Hidden_2'))
neural.add(keras.layers.Dense(units=16, activation='relu', name='Hidden_3'))
neural.add(keras.layers.Dense(units=3, activation='sigmoid', name='Output'))

neural.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 12288)             0
#
#  Hidden_1 (Dense)            (None, 256)               3145984
#
#  Hidden_2 (Dense)            (None, 64)                16448
#
#  Hidden_3 (Dense)            (None, 16)                1040
#
#  Output (Dense)              (None, 3)                 51
#
# =================================================================
# Total params: 3,163,523
# Trainable params: 3,163,523
# Non-trainable params: 0
# _________________________________________________________________

# %%
neural.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.RMSprop(),
    metrics=keras.metrics.BinaryAccuracy()
)

history = neural.fit(
    x=x_train,
    y=y_train,
    epochs=20,
    batch_size=40,
    verbose=2,
    validation_data=(x_test, y_test)
)

history.history.keys()
# Out:
# Epoch 1/20
# 250/250 - 4s - loss: 0.7274 - binary_accuracy: 0.6082 - val_loss: 0.6756 - val_binary_accuracy: 0.6117 - 4s/epoch - 17ms/step
# Epoch 2/20
# 250/250 - 4s - loss: 0.6708 - binary_accuracy: 0.6132 - val_loss: 0.6662 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 3/20
# 250/250 - 4s - loss: 0.6648 - binary_accuracy: 0.6132 - val_loss: 0.6625 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 4/20
# 250/250 - 4s - loss: 0.6628 - binary_accuracy: 0.6132 - val_loss: 0.6615 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 5/20
# 250/250 - 4s - loss: 0.6623 - binary_accuracy: 0.6132 - val_loss: 0.6612 - val_binary_accuracy: 0.6117 - 4s/epoch - 14ms/step
# Epoch 6/20
# 250/250 - 4s - loss: 0.6622 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 7/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 8/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 9/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 10/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 11/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 12/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 13/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 14/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 15/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 16/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 17/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 18/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# Epoch 19/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 14ms/step
# Epoch 20/20
# 250/250 - 4s - loss: 0.6621 - binary_accuracy: 0.6132 - val_loss: 0.6610 - val_binary_accuracy: 0.6117 - 4s/epoch - 15ms/step
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])
